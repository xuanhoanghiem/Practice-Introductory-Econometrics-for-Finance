# %% [markdown]
# <a href="https://colab.research.google.com/github/xuanhoanghiem/Practice-Introductory-Econometrics-for-Finance/blob/main/Chapter_2_Sargent_Setting_up_your_Python_environment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute pie slices
N=20
theta=np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii=10 * np.random.rand(N)
width=np.pi/4 * np.random.rand(N)
colors=plt.cm.viridis(radii/10.)
ax=plt.subplot(111,projection='polar')
ax.bar(theta, radii, width=width, bottom=0.0, color=colors, alpha=0.5)
plt.show()

# %%
# !pip install arch
# Out:
# ...
#      |████████████████████████████████| 808kB 2.8MB/s
# ...

# %%
# !pip install linearmodels
# Out:
# ...
#      |████████████████████████████████| 1.5MB 3.9MB/s
# ...
#      |████████████████████████████████| 9.5MB 23.2MB/s
# ...
#   Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# ...

# %%
np.random?

# %%
# !pip install quantecon
# Out:
# ...
#      |████████████████████████████████| 235kB 4.0MB/s
# ...

# %%
# !pip install interpolation
# Out:
# ...
#      |████████████████████████████████| 61kB 2.6MB/s
# ...
#   Created wheel for tempita: filename=Tempita-0.5.2-cp37-none-any.whl size=12882 sha256=5adb3ab9e51ef68938ad432820b0482d3f5451c0dd0d954c08942c2051c6855f
#   Stored in directory: /root/.cache/pip/wheels/1e/db/04/d827f417f162a149fbdfdd1d015c7769b393124aa98eb29642
# Successfully built tempita
# ...

# %%
# So far we have focused on executing Python code entered into a Jupyter notebook cell.
# However, traditionally, most Python code has been run in different way.
# Code is first saved into a text file on a local machine. 
# By convention, these text files have a ".py" extension.
# Example:
# %%file foo.py
print('foobar')
# Out:
# Overwriting foo.py

# %%
pip show numpy
# Out:
# Name: numpy
# Version: 1.19.5
# Summary: NumPy is the fundamental package for array computing with Python.
# Home-page: https://www.numpy.org
# Author: Travis E. Oliphant et al.
# Author-email: None
# License: BSD
# Location: /usr/local/lib/python3.7/dist-packages
# Requires:
# ...

# %%
pip show linearmodels
# Out:
# Name: linearmodels
# Version: 4.24
# Summary: Linear Panel, Instrumental Variable, Asset Pricing, and System Regression models for Python
# Home-page: http://github.com/bashtage/linearmodels
# Author: Kevin Sheppard
# Author-email: kevin.k.sheppard@gmail.com
# License: NCSA
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: property-cached, pandas, numpy, statsmodels, Cython, patsy, mypy-extensions, scipy, pyhdfe
# Required-by:

# %%
pip show arch
# Out:
# Name: arch
# Version: 4.19
# Summary: ARCH for Python
# Home-page: http://github.com/bashtage/arch
# Author: Kevin Sheppard
# Author-email: kevin.sheppard@economics.ox.ac.uk
# License: NCSA
# Location: /usr/local/lib/python3.7/dist-packages
# Requires: numpy, property-cached, cython, statsmodels, pandas, scipy
# Required-by:
